# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df.head(2)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1

# %%
df_cp = pd.get_dummies(df['cp'],drop_first=True)

# %%
df_cp.head(3)
# Out:
#        1      2      3
# 0  False  False   True
# 1  False   True  False
# 2   True  False  False

# %%
df = pd.concat([df,df_cp],axis=1)

# %%
df.head(3)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
#
#    caa  thall  output      1      2      3
# 0    0      1       1  False  False   True
# 1    0      2       1  False   True  False
# 2    0      2       1   True  False  False

# %%
df['cp_0'] = df[1].map({False:0,True:1})
df['cp_1'] = df[2].map({False:0,True:1})
df['cp_2'] = df[3].map({False:0,True:1})

# %%
df.head(3)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
#
#    caa  thall  output      1      2      3  cp_0  cp_1  cp_2
# 0    0      1       1  False  False   True     0     0     1
# 1    0      2       1  False   True  False     0     1     0
# 2    0      2       1   True  False  False     1     0     0

# %%
df.drop(['cp',1,2,3],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    age  sex  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# 0   63    1     145   233    1        0       150     0      2.3    0    0
# 1   37    1     130   250    0        1       187     0      3.5    0    0
#
#    thall  output  cp_0  cp_1  cp_2
# 0      1       1     0     0     1
# 1      2       1     0     1     0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'exng',
#        'oldpeak', 'slp', 'caa', 'thall', 'output', 'cp_0', 'cp_1', 'cp_2'],
#       dtype='object')
